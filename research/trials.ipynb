# %%
import google.generativeai as genai

# %%
GOOGLE_API_KEY = "AIzaSyAZwDV4ELT5trTDBJ54ks3pyY6UtAWTmfA"

user_text2 = "Write a detailed research paper on the applications of AI in healthcare."
user_text1 = "gimme the bangla translation of 'Good Morning'"
user_text3 = "Create a marketing plan for a new eco-friendly product."


genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel("gemini-2.0-flash")
response = model.generate_content(user_text1)
results = response.text
print(results)
# Out:
# The most common and natural translation of "Good Morning" in Bangla is:
#
# **শুভ সকাল** (Shuvo sokal)
#
# This is the standard and widely used greeting.
